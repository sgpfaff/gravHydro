# %%
import gravhydro as gh

# %%
gh.density_i()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 gh.density_i()
#
# TypeError: density_i() missing 4 required positional arguments: 'r', 'rs', 'masses', and 'h'
